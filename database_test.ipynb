# %% [markdown]
# # Database Connectivity Test
# Use this notebook to verify MySQL connectivity from Python if needed.

# %%
# Example (optional): install mysql-connector-python then connect
# import mysql.connector
# conn = mysql.connector.connect(host='localhost', user='4104', password='abc4104', database='G4104')
# print(conn.is_connected())
# conn.close()
